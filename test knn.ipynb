# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("weather_classification_data.csv")
data
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0             14.0        73         9.5               82.0  partly cloudy
# 1             39.0        96         8.5               71.0  partly cloudy
# 2             30.0        64         7.0               16.0          clear
# 3             38.0        83         1.5               82.0          clear
# 4             27.0        74        17.0               66.0       overcast
# ...            ...       ...         ...                ...            ...
# 13195         10.0        74        14.5               71.0       overcast
# 13196         -1.0        76         3.5               23.0         cloudy
# 13197         30.0        77         5.5               28.0       overcast
# 13198          3.0        76        10.0               94.0       overcast
# 13199         -5.0        38         0.0               92.0       overcast
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data["Cloud Cover"]=le.fit_transform(data["Cloud Cover"])
data
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  Cloud Cover  \
# 0             14.0        73         9.5               82.0            3
# 1             39.0        96         8.5               71.0            3
# 2             30.0        64         7.0               16.0            0
# 3             38.0        83         1.5               82.0            0
# 4             27.0        74        17.0               66.0            2
# ...            ...       ...         ...                ...          ...
# 13195         10.0        74        14.5               71.0            2
# 13196         -1.0        76         3.5               23.0            1
# 13197         30.0        77         5.5               28.0            2
# 13198          3.0        76        10.0               94.0            2
# 13199         -5.0        38         0.0               92.0            2
#
#        Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# ...

# %%
data["Season"]=le.fit_transform(data["Season"])
data
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  Cloud Cover  \
# 0             14.0        73         9.5               82.0            3
# 1             39.0        96         8.5               71.0            3
# 2             30.0        64         7.0               16.0            0
# 3             38.0        83         1.5               82.0            0
# 4             27.0        74        17.0               66.0            2
# ...            ...       ...         ...                ...          ...
# 13195         10.0        74        14.5               71.0            2
# 13196         -1.0        76         3.5               23.0            1
# 13197         30.0        77         5.5               28.0            2
# 13198          3.0        76        10.0               94.0            2
# 13199         -5.0        38         0.0               92.0            2
#
#        Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# ...

# %%
data["Location"]=le.fit_transform(data["Location"])
data
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  Cloud Cover  \
# 0             14.0        73         9.5               82.0            3
# 1             39.0        96         8.5               71.0            3
# 2             30.0        64         7.0               16.0            0
# 3             38.0        83         1.5               82.0            0
# 4             27.0        74        17.0               66.0            2
# ...            ...       ...         ...                ...          ...
# 13195         10.0        74        14.5               71.0            2
# 13196         -1.0        76         3.5               23.0            1
# 13197         30.0        77         5.5               28.0            2
# 13198          3.0        76        10.0               94.0            2
# 13199         -5.0        38         0.0               92.0            2
#
#        Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# ...

# %%
data["Location"].value_counts()
# Out:
# Location
# 1    4816
# 2    4813
# 0    3571
# Name: count, dtype: int64

# %%
#data.replace({"Season":{"Winter":0,"Spring":1,"Summer":2,"Autumn":3}},inplace=True)

# %%
#data.replace({"Location":{"inland":0,"mountain":1,"coastal":2}},inplace=True)

# %%
#data.replace({"Cloud Cover":{"clear":0,"partly cloudy":1,"overcast":2}},inplace=True)

# %%
#data.replace({"Weather Type":{"Sunny":0,"Cloudy":1,"Rainy":2}},inplace=True)

# %%
x=data.drop("Weather Type",axis=1)
y=data["Weather Type"]

# %%
x
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  Cloud Cover  \
# 0             14.0        73         9.5               82.0            3
# 1             39.0        96         8.5               71.0            3
# 2             30.0        64         7.0               16.0            0
# 3             38.0        83         1.5               82.0            0
# 4             27.0        74        17.0               66.0            2
# ...            ...       ...         ...                ...          ...
# 13195         10.0        74        14.5               71.0            2
# 13196         -1.0        76         3.5               23.0            1
# 13197         30.0        77         5.5               28.0            2
# 13198          3.0        76        10.0               94.0            2
# 13199         -5.0        38         0.0               92.0            2
#
#        Atmospheric Pressure  UV Index  Season  Visibility (km)  Location
# ...

# %%
y
# Out:
# 0         Rainy
# 1        Cloudy
# 2         Sunny
# 3         Sunny
# 4         Rainy
#           ...
# 13195     Rainy
# 13196     Snowy
# 13197    Cloudy
# 13198     Snowy
# 13199     Rainy
# Name: Weather Type, Length: 13200, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4,random_state=45)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=7)
classifier.fit(x_train,y_train) #Training
y_pred = classifier.predict(x_test)

# %%
y_pred
# Out:
# array(['Rainy', 'Cloudy', 'Rainy', ..., 'Sunny', 'Snowy', 'Rainy'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
print(accuracy_score(y_pred,y_test))
# Out:
# 0.8952651515151515

# %%
print(confusion_matrix(y_pred,y_test))
# Out:
# [[1168   87   45   80]
#  [ 103 1207   32   42]
#  [  28   34 1222   16]
#  [  34   25   27 1130]]

# %%
classifier.predict([[67,37,9.66,35,97.99,23,0.76,8.46,36,23.4]])
# Out:
# array(['Sunny'], dtype=object)
